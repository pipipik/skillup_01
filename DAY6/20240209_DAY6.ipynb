# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = pd.read_csv("./tips/tips.csv")

# %%
sns.countplot(tips.day)
plt.show()
# Out:
# /Users/hiroya/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(tips.day,tips.total_bill)
plt.show()
# Out:
# /Users/hiroya/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.distplot(tips.total_bill,bins=20, kde = False)
plt.show()
# Out:
# /Users/hiroya/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.regplot(tips.total_bill,tips.tip, fit_reg=False)
plt.show()
# Out:
# /Users/hiroya/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig,ax=plt.subplots(1,2,figsize=(10,5))
sns.countplot(tips.day,ax=ax[0])
sns.regplot(tips.total_bill,tips.tip,ax = ax[1])
plt.show()
# Out:
# /Users/hiroya/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/hiroya/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(tips.smoker)
# Out:
# /Users/hiroya/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.distplot(tips.tip, bins=20, kde = False)
# Out:
# /Users/hiroya/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tip'>

# %%
sns.regplot(tips.total_bill, tips.tip, fit_reg=False)
# Out:
# /Users/hiroya/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# Seabornを用いた可視化
# 問題1
fig, ax = plt.subplots(1, 3)
sns.countplot(tips.smoker, ax=ax[0])
sns.distplot(tips.tip, kde=False, ax=ax[1])
sns.regplot(tips.total_bill, tips.tip, fit_reg=False, ax=ax[2])
plt.show()
# Out:
# /Users/hiroya/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/hiroya/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/hiroya/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# 量的変数(数字で表されているデータ)の組み合わせ分だけ、ヒストグラム・散布図を表示
sns.pairplot(tips)
plt.show()

# %%
tips.corr().style.background_gradient("summer_r")
# Out:
# <style type="text/css">
# #T_ea9fa_row0_col0, #T_ea9fa_row1_col1, #T_ea9fa_row2_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_ea9fa_row0_col1 {
#   background-color: #a2d066;
#   color: #000000;
# }
# #T_ea9fa_row0_col2 {
#   background-color: #c9e466;
#   color: #000000;
# }
# #T_ea9fa_row1_col0 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_ea9fa_row1_col2, #T_ea9fa_row2_col0, #T_ea9fa_row2_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# </style>
# <table id="T_ea9fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea9fa_level0_col0" class="col_heading level0 col0" >total_bill</th>
#       <th id="T_ea9fa_level0_col1" class="col_heading level0 col1" >tip</th>
#       <th id="T_ea9fa_level0_col2" class="col_heading level0 col2" >size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea9fa_level0_row0" class="row_heading level0 row0" >total_bill</th>
#       <td id="T_ea9fa_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ea9fa_row0_col1" class="data row0 col1" >0.675734</td>
#       <td id="T_ea9fa_row0_col2" class="data row0 col2" >0.598315</td>
#     </tr>
#     <tr>
#       <th id="T_ea9fa_level0_row1" class="row_heading level0 row1" >tip</th>
#       <td id="T_ea9fa_row1_col0" class="data row1 col0" >0.675734</td>
#       <td id="T_ea9fa_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ea9fa_row1_col2" class="data row1 col2" >0.489299</td>
#     </tr>
#     <tr>
#       <th id="T_ea9fa_level0_row2" class="row_heading level0 row2" >size</th>
#       <td id="T_ea9fa_row2_col0" class="data row2 col0" >0.598315</td>
#       <td id="T_ea9fa_row2_col1" class="data row2 col1" >0.489299</td>
#       <td id="T_ea9fa_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.heatmap(tips.corr(),cmap="summer_r")
plt.show()

# %%
sns.swarmplot("day","total_bill",data=tips,hue="sex",dodge=True)
# Out:
# /Users/hiroya/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(tips.day,tips.tip,hue=tips.sex)
plt.show()
# Out:
# /Users/hiroya/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Seabornの強み
# 問題1
sns.pairplot(tips[["total_bill", "tip"]])
plt.show()

# %%
# 問題2
sns.boxplot(tips.sex, tips.tip, hue= tips.day)
plt.show()
# Out:
# /Users/hiroya/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# 可視化総合演習
# 問題1
house = pd.read_csv("./house/house_data.csv")
house["price_jp"] = house.price*100
plt.scatter(house.price_jp, house.sqft_living, s=1, color)
plt.show()
# Out:
# Text(0, 0.5, 'sqft_liiving')

# %%
house.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  condition  grade  sqft_above  sqft_basement  yr_built    price_jp
# 0      5650          3      7        1180              0      1955  22190000.0
# 1      7242          3      7        2170            400      1951  53800000.0
# 2     10000          3      6         770              0      1933  18000000.0
# 3      5000          5      7        1050            910      1965  60400000.0
# 4      8080          3      8        1680              0      1987  51000000.0
